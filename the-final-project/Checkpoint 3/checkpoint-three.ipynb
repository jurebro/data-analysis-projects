# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).

# %%
# Import Libraries
import pandas as pd
import numpy as np

# Dataframe Creation
df_gtd = pd.read_csv("gtd_uk_usa.csv")
df_us_elections = [2000, 2004, 2008, 2012, 2016, 2020, 2024]
df_uk_elections = pd.read_csv("uk-gen_elections-voteshare-trunc.csv")

# %%
# Reviewing basic dataframe information

df_gtd.info()
df_gtd.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Columns: 110 entries, eventid to related
# dtypes: float64(42), int64(21), object(47)
# memory usage: 1.7+ MB
# (1999, 110)

# %%
df_gtd.head(6)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0  200001010027   2000       1     1        NaN         0        NaN
# 1  200001030007   2000       1     3        NaN         0        NaN
# 2  200001030008   2000       1     3        NaN         0        NaN
# 3  200001030009   2000       1     3        NaN         0        NaN
# 4  200001070003   2000       1     7        NaN         0        NaN
# 5  200001100001   2000       1    10        NaN         0        NaN
#
#       country_txt      region_txt         provstate  ...  \
# 0   United States   North America          Michigan  ...
# 1   United States   North America        California  ...
# 2   United States   North America              Ohio  ...
# 3   United States   North America              Ohio  ...
# 4  United Kingdom  Western Europe  Northern Ireland  ...
# 5  United Kingdom  Western Europe  Northern Ireland  ...
#
#                                             addnotes  \
# 0  The four perpetrators were also indicted for t...
# 1                                                NaN
# 2                                                NaN
# 3  This is part of a multiple attack with 2000010...
# 4  Denver Smith, 32, had been murdered at the sam...
# 5                                                NaN
#
#                                               scite1  \
# 0  "AG Hall Arsonist Sentenced to 21 Years in Pri...
# 1  "Animal Liberation Front says they attack Cali...
# 2  "Abortion Clinics Evacuated After Threats of A...
# 3  "Abortion Clinics Evacuated After Threats of A...
# 4  “Blast in N. Ireland Town; None Injured,” Pres...
# 5  David Sharrock, “Ulster Terrorist Leader Murde...
#
#                                               scite2  \
# 0  Art Bukowski, "Activists planned MSU arson plo...
# 1  FBI "Terrorism in the United States 2000/2001"...
# 2  Patricia Baird-Windle and Eleanor J. Bader, "T...
# 3  Patricia Baird-Windle and Eleanor J. Bader, "T...
# 4                                                NaN
# 5  Chris Anderson, “Ulster Police Expect Loyalist...
#
#                                               scite3  \
# 0  Justice Department Documents and Publications,...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Deric Henderson, “UK: LVF Blamed After Rival L...
#
#                      dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  \
# 0            Eco Project 2010        0         1         0        1
# 1                       CETIS        0         1         0        1
# 2  Anti-Abortion Project 2010       -9        -9         0       -9
# 3  Anti-Abortion Project 2010       -9        -9         0       -9
# 4                       CETIS       -9        -9         1        1
# 5                       CETIS        0         0         1        1
#
#                       related
# 0                         NaN
# 1                         NaN
# 2  200001030008, 200001030009
# 3  200001030008, 200001030009
# 4                         NaN
# 5                         NaN
#
# [6 rows x 110 columns]

# %%
df_uk_elections.info()
df_uk_elections.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   party_name  90 non-null     object
#  1   alignment   90 non-null     object
#  2   vote_share  78 non-null     float64
#  3   vote_year   90 non-null     int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.9+ KB
# (90, 4)

# %%
df_uk_elections.head(6)
# Out:
#                 party_name       alignment  vote_share  vote_year
# 0                   Labour     centre-left      33.700       2024
# 1             Conservative    centre-right      23.704       2024
# 2                Reform UK  right-populism      14.293       2024
# 3         Liberal Democrat     centre-left      12.215       2024
# 4              Green Party            left       6.398       2024
# 5  Scottish National Party     centre-left       2.516       2024

# %% [markdown]
# <div class="alert alert-block alert-info">
# As I parsed and created the UK elections dataset and cleaned as I went, my focus throughout this checkpoint will be on the GTD dataset.
# </div>

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# Identifying that there are columns with null values.
# Sorted by descending and utilizing .pipe() with lambda to filter out any columns with 0 nulls.

df_gtd.isna().sum().pipe(lambda s: s[s > 0]).sort_values(ascending=False)
# Out:
# ransomamtus         1999
# kidhijcountry       1999
# divert              1999
# weapsubtype4_txt    1999
# weaptype4_txt       1999
#                     ...
# nkillter               4
# natlty1_txt            3
# nkillus                2
# target1                1
# ishostkid              1
# Length: 75, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# Understanding that there are 1999 entries in the dataset, we can see that there are columns that are entirely nulls. For our analysis with these two countries (USA and UK), a null value for ransom amount, kidnapping/hijacking country, diversion [from hijacking/kidnapping], etc. are not particularly interesting or valuable. As such, we can delete these columns.
# </div>

# %%
# Using the same logic to identify those columns that are entirely null values:

df_gtd.isna().sum().pipe(lambda s: s[s == 1999]).sort_values(ascending=False)
# Out:
# gname3              1999
# gsubname3           1999
# guncertain3         1999
# claim3              1999
# claimmode3          1999
# claimmode3_txt      1999
# weaptype4_txt       1999
# weapsubtype4_txt    1999
# divert              1999
# kidhijcountry       1999
# ransomamt           1999
# ransomamtus         1999
# ransompaid          1999
# ransompaidus        1999
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# The columns listed above are comprised entirely of null values. This shows that among the incidents in the United States and United Kingdom between 2000 and 2020, there were none that had a third group identified, if that third group name is uncertain or not, a third group claiming responsibility (and/or how), a fourth weapon type used, etc. Following the comment above, we can delete these columns, as well.
# </div>

# %%
# Creating a list of columns to drop for ease:

cols_to_drop = [
    "gname3",
    "gsubname3",
    "guncertain3",
    "claim3",
    "claimmode3",
    "claimmode3_txt",
    "weaptype4_txt",
    "weapsubtype4_txt",
    "kidhijcountry",
    "divert",
    "ransomamt",
    "ransomamtus",
    "ransompaid",
    "ransompaidus"
]

# Dropping the columns
df_gtd = df_gtd.drop(columns=cols_to_drop)

# %%
# Confirming dropped columns:

df_gtd.isna().sum().pipe(lambda s: s[s == 1999]).sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
# Identifying that there are columns with null values again.
# Sorted by descending and utilizing .pipe() with lambda to filter out any columns with 0 nulls.

df_gtd.isna().sum().pipe(lambda s: s[s > 0]).sort_values(ascending=False)
# Out:
# attacktype3        1998
# attacktype3_txt    1998
# ndays              1997
# claimmode2_txt     1994
# claimmode2         1994
#                    ...
# nwound                4
# natlty1_txt           3
# nkillus               2
# target1               1
# ishostkid             1
# Length: 61, dtype: int64

# %%
df_gtd.isna().sum()
# Out:
# eventid          0
# iyear            0
# imonth           0
# iday             0
# approxdate    1955
#               ...
# INT_LOG          0
# INT_IDEO         0
# INT_MISC         0
# INT_ANY          0
# related       1650
# Length: 110, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# From EDA performed in checkpoint 2, we also know that approxdate and related have null values. However, it is important to understand why 'approxdate' is null and why those entries with null values for it cannot be removed. The 'approxdate' column is used when there is only an approximate and not exact date of the incident, such that if an exact date is known, the approximate date value will be null. This suggests that of the 1999 entries, 44 of them only have an approximate date for the incident. While these could be removed, our analysis is utilizing incident year rather than specific dates. As such, there is no harm in keeping those entries. Alternatively, we could drop the column entirely as those entries with approximate dates do have values in the appropriate fields ('iyear', 'imonth') for that approximation.
# </div>

# %%
# Dropping the column 'approxdate':

df_gtd = df_gtd.drop(columns=["approxdate"])

# %%
# Sanity check:
"approxdate" in df_gtd
# Out:
# False

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
# Overview of the dataset using .describe()

df_gtd.describe()
# Out:
#             eventid        iyear       imonth         iday     extended  \
# count  1.999000e+03  1999.000000  1999.000000  1999.000000  1999.000000
# mean   2.012568e+11  2012.502751     6.350175    15.136568     0.004002
# std    6.353815e+08     6.351867     3.287590     8.787154     0.063150
# min    2.000010e+11  2000.000000     1.000000     0.000000     0.000000
# 25%    2.008082e+11  2008.000000     4.000000     8.000000     0.000000
# 50%    2.015011e+11  2015.000000     6.000000    15.000000     0.000000
# 75%    2.018013e+11  2018.000000     9.000000    23.000000     0.000000
# max    2.020123e+11  2020.000000    12.000000    31.000000     1.000000
#
#        specificity     vicinity        crit1        crit2        crit3  ...  \
# count  1999.000000  1999.000000  1999.000000  1999.000000  1999.000000  ...
# mean      1.013507     0.036018     0.960480     0.993997     0.996998  ...
# std       0.168363     0.186382     0.194877     0.077265     0.054717  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       1.000000     0.000000     1.000000     1.000000     1.000000  ...
# 50%       1.000000     0.000000     1.000000     1.000000     1.000000  ...
# 75%       1.000000     0.000000     1.000000     1.000000     1.000000  ...
# max       4.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#        nhostkidus     nhours      ndays      ransom  hostkidoutcome  \
# count   34.000000  33.000000   2.000000  115.000000       34.000000
# mean    -1.352941 -56.121212 -49.500000   -0.156522        3.235294
# std     36.628257  50.736918  70.003571    1.181668        1.670761
# min    -99.000000 -99.000000 -99.000000   -9.000000        2.000000
# 25%      0.000000 -99.000000 -74.250000    0.000000        2.000000
# 50%      0.000000 -99.000000 -49.500000    0.000000        2.000000
# 75%      1.000000   1.000000 -24.750000    0.000000        4.000000
# max     86.000000   5.000000   0.000000    0.000000        7.000000
#
#         nreleased      INT_LOG     INT_IDEO     INT_MISC      INT_ANY
# count   34.000000  1999.000000  1999.000000  1999.000000  1999.000000
# mean    -4.735294    -6.784892    -6.717359     0.592296    -2.397699
# std     48.779224     3.877730     4.002083     0.535395     4.722257
# min    -99.000000    -9.000000    -9.000000    -9.000000    -9.000000
# 25%      0.250000    -9.000000    -9.000000     0.000000    -9.000000
# 50%      1.000000    -9.000000    -9.000000     1.000000     1.000000
# 75%      1.000000    -9.000000    -9.000000     1.000000     1.000000
# max    200.000000     0.000000     1.000000     1.000000     1.000000
#
# [8 rows x 49 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# The above is not particularly helpful due to the number of columns, as well as the majority of the numerical values corresponding to a text value (see codebook) or a yes/no flag. Let's narrow down to a handful columns that do have possible quantitative significance. Numerical variable columns may also be identified by searching for 'Numerical Variable' within the codebook.
# </div>

# %%
df_gtd[["nperps","nperpcap","nkill","nkillus","nkillter","nwound","nwoundus","nwoundte"]].describe()
# Out:
#             nperps     nperpcap        nkill      nkillus     nkillter  \
# count  1790.000000  1972.000000  1999.000000  1997.000000  1995.000000
# mean    -61.523464    -2.736308     1.780890     1.652479     0.039098
# std      48.649305    17.219225    44.056259    42.759750     0.284108
# min     -99.000000   -99.000000     0.000000     0.000000     0.000000
# 25%     -99.000000     0.000000     0.000000     0.000000     0.000000
# 50%     -99.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     0.000000     0.000000     0.000000
# max      15.000000    11.000000  1385.000000  1361.000000     5.000000
#
#              nwound     nwoundus     nwoundte
# count   1995.000000  1987.000000  1992.000000
# mean      12.571429     0.385506     0.017570
# std      345.003475     3.990971     0.174152
# min        0.000000     0.000000     0.000000
# 25%        0.000000     0.000000     0.000000
# 50%        0.000000     0.000000     0.000000
# 75%        0.000000     0.000000     0.000000
# max    10878.000000   151.000000     4.000000

# %% [markdown]
# <div class="alert alert-block alert-info">
# There are outliers in this dataset when it comes to the number killed or wounded, particularly when taking into account mass casualty incidents, such as September 11, 2001. However, removing this outliers would remove important data points and a broader picture of incidents of terrorism over time. As such, they will not be removed.
# </div>

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %% [markdown]
# <div class="alert alert-block alert-info">
# As noted in Checkpoint 2:
# <div class="alert alert-block alert-success">
# <i>Prior to this EDA, I pre-emptively removed columns from the original dataset in order to reduce the size of the .csv. This included limiting the timeframe from 2000 to 2020, excluding the
# data from 1970 to 1999. This early cleaning also included removing the columns with numerical values that also had corresponding text values (e.g. 'country'; 'country_txt') or those with
# interesting qualitative information but not useful in a quantitative analysis without further coding (e.g. 'summary'). Some of these fields were left to add additional context for future
# reviewers (e.g. source citations). Other fields, also with potentially valuable information but outside the scope of this project, were also removed, such as latitude/longitude.</i>>
# </div>
# <br>
# As such, much of the unnecessary data has already been removed from the dataset before beginning EDA and further with Checkpoint 3.
# </div>

# %%
# Reviewing the current dataframe:

df_gtd.head(6)
# Out:
#         eventid  iyear  imonth  iday  extended resolution     country_txt  \
# 0  200001010027   2000       1     1         0        NaN   United States
# 1  200001030007   2000       1     3         0        NaN   United States
# 2  200001030008   2000       1     3         0        NaN   United States
# 3  200001030009   2000       1     3         0        NaN   United States
# 4  200001070003   2000       1     7         0        NaN  United Kingdom
# 5  200001100001   2000       1    10         0        NaN  United Kingdom
#
#        region_txt         provstate        city  ...  \
# 0   North America          Michigan      Mesick  ...
# 1   North America        California    Petaluma  ...
# 2   North America              Ohio  Cincinnati  ...
# 3   North America              Ohio  Cincinnati  ...
# 4  Western Europe  Northern Ireland      Antrim  ...
# 5  Western Europe  Northern Ireland   Portadown  ...
#
#                                             addnotes  \
# 0  The four perpetrators were also indicted for t...
# 1                                                NaN
# 2                                                NaN
# 3  This is part of a multiple attack with 2000010...
# 4  Denver Smith, 32, had been murdered at the sam...
# 5                                                NaN
#
#                                               scite1  \
# 0  "AG Hall Arsonist Sentenced to 21 Years in Pri...
# 1  "Animal Liberation Front says they attack Cali...
# 2  "Abortion Clinics Evacuated After Threats of A...
# 3  "Abortion Clinics Evacuated After Threats of A...
# 4  “Blast in N. Ireland Town; None Injured,” Pres...
# 5  David Sharrock, “Ulster Terrorist Leader Murde...
#
#                                               scite2  \
# 0  Art Bukowski, "Activists planned MSU arson plo...
# 1  FBI "Terrorism in the United States 2000/2001"...
# 2  Patricia Baird-Windle and Eleanor J. Bader, "T...
# 3  Patricia Baird-Windle and Eleanor J. Bader, "T...
# 4                                                NaN
# 5  Chris Anderson, “Ulster Police Expect Loyalist...
#
#                                               scite3  \
# 0  Justice Department Documents and Publications,...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Deric Henderson, “UK: LVF Blamed After Rival L...
#
#                      dbsource  INT_LOG  INT_IDEO  INT_MISC INT_ANY  \
# 0            Eco Project 2010        0         1         0       1
# 1                       CETIS        0         1         0       1
# 2  Anti-Abortion Project 2010       -9        -9         0      -9
# 3  Anti-Abortion Project 2010       -9        -9         0      -9
# 4                       CETIS       -9        -9         1       1
# 5                       CETIS        0         0         1       1
#
#                       related
# 0                         NaN
# 1                         NaN
# 2  200001030008, 200001030009
# 3  200001030008, 200001030009
# 4                         NaN
# 5                         NaN
#
# [6 rows x 95 columns]

# %%
# Because we are limited to the United States and United Kingdom with country_txt, the region_txt does not add any value. This can be dropped.
# Dropping 'region_txt' column:

df_gtd = df_gtd.drop(columns=["region_txt"])

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
df_gtd.head(51)
# Out:
#          eventid  iyear  imonth  iday  extended resolution     country_txt  \
# 0   200001010027   2000       1     1         0        NaN   United States
# 1   200001030007   2000       1     3         0        NaN   United States
# 2   200001030008   2000       1     3         0        NaN   United States
# 3   200001030009   2000       1     3         0        NaN   United States
# 4   200001070003   2000       1     7         0        NaN  United Kingdom
# 5   200001100001   2000       1    10         0        NaN  United Kingdom
# 6   200001150004   2000       1    15         0        NaN   United States
# 7   200001200002   2000       1    20         0        NaN   United States
# 8   200001240007   2000       1    24         0        NaN   United States
# 9   200002060001   2000       2     6         0        NaN  United Kingdom
# 10  200002250001   2000       2    25         0        NaN  United Kingdom
# 11  200002250004   2000       2    25         0        NaN  United Kingdom
# 12  200002250007   2000       2    25         0        NaN   United States
# 13  200003010004   2000       3     1         0        NaN   United States
# 14  200003010005   2000       3     1         0        NaN   United States
# 15  200003010006   2000       3     1         0        NaN   United States
# 16  200003010007   2000       3     1         0        NaN   United States
# 17  200003120004   2000       3    12         0        NaN   United States
# 18  200003220005   2000       3    22         0        NaN   United States
# 19  200003250005   2000       3    25         0        NaN   United States
# 20  200004030006   2000       4     3         0        NaN   United States
# 21  200004060001   2000       4     6         0        NaN  United Kingdom
# 22  200004090003   2000       4     9         0        NaN   United States
# 23  200004130001   2000       4    13         0        NaN  United Kingdom
# 24  200004140004   2000       4    14         0        NaN   United States
# 25  200004280003   2000       4    28         0        NaN   United States
# 26  200004280004   2000       4    28         0        NaN   United States
# 27  200004280005   2000       4    28         0        NaN   United States
# 28  200004280006   2000       4    28         0        NaN   United States
# 29  200004280007   2000       4    28         0        NaN   United States
# 30  200004280008   2000       4    28         0        NaN   United States
# 31  200005020004   2000       5     2         0        NaN  United Kingdom
# 32  200005070004   2000       5     7         0        NaN   United States
# 33  200005210002   2000       5    21         0        NaN  United Kingdom
# 34  200005270008   2000       5    27         0        NaN   United States
# 35  200005270009   2000       5    27         0        NaN   United States
# 36  200006060003   2000       6     6         0        NaN  United Kingdom
# 37  200006070004   2000       6     7         0        NaN  United Kingdom
# 38  200006160006   2000       6    16         0        NaN   United States
# 39  200006170004   2000       6    17         0        NaN  United Kingdom
# 40  200006190003   2000       6    19         0        NaN  United Kingdom
# 41  200006210001   2000       6    21         0        NaN  United Kingdom
# 42  200006210002   2000       6    21         0        NaN  United Kingdom
# 43  200006300001   2000       6    30         0        NaN  United Kingdom
# 44  200006300004   2000       6    30         0        NaN  United Kingdom
# 45  200007000001   2000       7     0         0        NaN  United Kingdom
# 46  200007020009   2000       7     2         0        NaN   United States
# 47  200007050003   2000       7     5         0        NaN  United Kingdom
# 48  200007090001   2000       7     9         0        NaN  United Kingdom
# 49  200007150005   2000       7    15         0        NaN  United Kingdom
# 50  200007170005   2000       7    17         0        NaN  United Kingdom
#
#            provstate          city  specificity  ...  \
# 0           Michigan        Mesick          1.0  ...
# 1         California      Petaluma          1.0  ...
# 2               Ohio    Cincinnati          1.0  ...
# 3               Ohio    Cincinnati          1.0  ...
# 4   Northern Ireland        Antrim          1.0  ...
# 5   Northern Ireland     Portadown          1.0  ...
# 6         California      Petaluma          1.0  ...
# 7            Indiana   Bloomington          1.0  ...
# 8         California  Redwood City          1.0  ...
# 9   Northern Ireland   Irvinestown          1.0  ...
# 10  Northern Ireland    Ballykelly          1.0  ...
# 11  Northern Ireland     Portadown          1.0  ...
# 12        California       Fremont          1.0  ...
# 13      Pennsylvania   Wilkinsburg          1.0  ...
# 14      Pennsylvania   Wilkinsburg          1.0  ...
# 15      Pennsylvania   Wilkinsburg          1.0  ...
# 16      Pennsylvania   Wilkinsburg          1.0  ...
# 17         Wisconsin       Viroqua          1.0  ...
# 18              Utah         Ogden          1.0  ...
# 19           Arizona      Chandler          1.0  ...
# 20          Missouri   Kansas City          1.0  ...
# 21  Northern Ireland   Londonderry          1.0  ...
# 22           Arizona       Phoenix          1.0  ...
# 23  Northern Ireland       Rosslea          1.0  ...
# 24           Florida  Oakland Park          1.0  ...
# 25      Pennsylvania    Pittsburgh          1.0  ...
# 26      Pennsylvania    Pittsburgh          1.0  ...
# 27      Pennsylvania    Pittsburgh          1.0  ...
# 28      Pennsylvania    Pittsburgh          1.0  ...
# 29      Pennsylvania    Pittsburgh          1.0  ...
# 30      Pennsylvania        Monaca          1.0  ...
# 31  Northern Ireland     Dungannon          1.0  ...
# 32        Washington       Olympia          1.0  ...
# 33           England        Witney          1.0  ...
# 34     New Hampshire       Concord          1.0  ...
# 35            Oregon        Eugene          1.0  ...
# 36  Northern Ireland       Belfast          1.0  ...
# 37  Northern Ireland      Annalong          1.0  ...
# 38            Oregon        Eugene          1.0  ...
# 39  Northern Ireland   Londonderry          1.0  ...
# 40  Northern Ireland  Hillsborough          1.0  ...
# 41  Northern Ireland       Belfast          1.0  ...
# 42  Northern Ireland   Londonderry          1.0  ...
# 43  Northern Ireland       Belfast          1.0  ...
# 44  Northern Ireland         Newry          1.0  ...
# 45  Northern Ireland     Ballymena          3.0  ...
# 46           Indiana  North Vernon          1.0  ...
# 47  Northern Ireland      Drumcree          1.0  ...
# 48  Northern Ireland  Stewartstown          1.0  ...
# 49  Northern Ireland  Castlewellan          1.0  ...
# 50  Northern Ireland     Ballymena          1.0  ...
#
#                                              addnotes  \
# 0   The four perpetrators were also indicted for t...
# 1                                                 NaN
# 2                                                 NaN
# 3   This is part of a multiple attack with 2000010...
# 4   Denver Smith, 32, had been murdered at the sam...
# 5                                                 NaN
# 6                                                 NaN
# 7   Homeowners and the Indiana Crime and Arson ass...
# 8                                                 NaN
# 9                                                 NaN
# 10  The Continuity IRA (CIRA) claimed responsibili...
# 11                                                NaN
# 12                                                NaN
# 13  Although there is evidence that this series of...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19           The incident occurred at about 6:15 a.m.
# 20                                                NaN
# 21                                                NaN
# 22  Sands claimed the home was obstructing his jog...
# 23                                                NaN
# 24  Damages to the facility were estimated to be b...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  The fire was ignited at 10:00 PM.  Fifteen min...
# 35  The perpetrators were also responsible and sen...
# 36  The three vehicles all had Republic number pla...
# 37                                                NaN
# 38  The perpetrators were also responsible and sen...
# 39  Helen Wray believed that fellow Protestants we...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46  Incident occurred just before 11:30 p.m. There...
# 47                                                NaN
# 48                                                NaN
# 49  The Loyalist Volunteer Force (LVF) had earlier...
# 50                                                NaN
#
#                                                scite1  \
# 0   "AG Hall Arsonist Sentenced to 21 Years in Pri...
# 1   "Animal Liberation Front says they attack Cali...
# 2   "Abortion Clinics Evacuated After Threats of A...
# 3   "Abortion Clinics Evacuated After Threats of A...
# 4   “Blast in N. Ireland Town; None Injured,” Pres...
# 5   David Sharrock, “Ulster Terrorist Leader Murde...
# 6          FBI, "Terrorism 2000/2001,"FBI, DOJ, 2001.
# 7   Associated Press. "Bloomington house fire rewa...
# 8   James W. Sweeney, "Rights Group Takes Credit f...
# 9   “Bomb Explodes at Northern Ireland Hotel,” Lon...
# 10  “IRA Rebels Target British Troops On UK Mainla...
# 11  “Appeal for Calm After Portadown Shooting,” Pr...
# 12  James W. Sweeney, "Animal Activists Blamed in ...
# 13  Michael A. Fuoco, "Residents remember the dead...
# 14  Michael A. Fuoco, "Residents remember the dead...
# 15  Michael A. Fuoco, "Residents remember the dead...
# 16  Michael A. Fuoco, "Residents remember the dead...
# 17  Doug Cunningham, "Animal Liberation Front atte...
# 18  Matthew Ott, “IRS Receiving Room Quarantined A...
# 19  "Man hurt after package bomb explodes in home,...
# 20  “Metropolitan Digest,” The Kansas City Star, A...
# 21  “Blast Damages Northern Ireland army camp,” Un...
# 22         FBI, "Terrorism 2000/2001,"FBI, DOJ, 2001.
# 23  Henderson, Deric, “Real Irish Republican Army ...
# 24  "Broward Abortion Clinic Set On Fire, Vandaliz...
# 25  "Cold killer's 20-mile trail leaves 5 dead," P...
# 26  "Cold killer's 20-mile trail leaves 5 dead," P...
# 27  "Cold killer's 20-mile trail leaves 5 dead," P...
# 28  "Cold killer's 20-mile trail leaves 5 dead," P...
# 29  "Cold killer's 20-mile trail leaves 5 dead," P...
# 30  "Cold killer's 20-mile trail leaves 5 dead," P...
# 31  Suzanne Breen,"IRA Believed to Have Brutally B...
# 32  FBI "Terrorism in the United States 2000/2001"...
# 33  Paul Kelso, "Animal Activists Suspected of Bla...
# 34  "N.H. Abortion Clinic Fire May Have Been An Ar...
# 35  Rebecca Taylor, "Activist's arson sentence red...
# 36  "Terrorist firebomb hols hell", The Sun, June ...
# 37  "Two Escape Injury in Northern Ireland Pipe-Bo...
# 38  Allison Tallmadge, "Activist found guilty of A...
# 39  “Protestants Blamed for Gun Attack,” Century N...
# 40  Nicholas Watt and Maggie O'Kane, "Loyalists wa...
# 41  “Arrest made after Belfast blast hurts Catholi...
# 42  “Arrest made after Belfast blast hurts Catholi...
# 43  “Belfast: Lone IRA Gunman Routs Loyalist Gang,...
# 44  Edward F. Mickolus, Terrorism, 1996-2001 : A C...
# 45  "Mayor blasts wave of fire attacks," Belfast N...
# 46         FBI, "Terrorism 2000/2001,"FBI, DOJ, 2001.
# 47  "Police Attacked with Acid and Stone," The Roy...
# 48  "Car bomb explodes outside N Ireland police st...
# 49  Neil Mackay, “Loyalists paramilitaries planted...
# 50  "Mayor blasts wave of fire attacks," Belfast N...
#
#                                                scite2  \
# 0   Art Bukowski, "Activists planned MSU arson plo...
# 1   FBI "Terrorism in the United States 2000/2001"...
# 2   Patricia Baird-Windle and Eleanor J. Bader, "T...
# 3   Patricia Baird-Windle and Eleanor J. Bader, "T...
# 4                                                 NaN
# 5   Chris Anderson, “Ulster Police Expect Loyalist...
# 6   Suzanne Bohan, "Some cage-free egg producers f...
# 7   Associated Press "Local ELF group feels backla...
# 8   "Animal Liberation Front Says They Attacked Ca...
# 9   “IRA Dissidents Suspected in Bombing,” Associa...
# 10  “Two Held Over Blast at Ulster Barracks,” Pres...
# 11  “UK: Man Shot in Portadown Loyalist Housing Es...
# 12  Pamela J. Podger, "Animal-Rights Cell Says It ...
# 13  Todd Spangler, "Pa. gunman kills 2, surrenders...
# 14  Todd Spangler, "Pa. gunman kills 2, surrenders...
# 15  Todd Spangler, "Pa. gunman kills 2, surrenders...
# 16  Todd Spangler, "Pa. gunman kills 2, surrenders...
# 17  “Animal Liberation Front Attacks Mink Business...
# 18  “3 at IRS Get Rash From Toxic Mailing,” The De...
# 19  Christopher Hewitt, "Political Violence and Te...
# 20  “Across the USA News from Every State,” USA To...
# 21  Hayes, Dominic, “Security Review After Bomb At...
# 22  Foster Klug, "Arsonist who tried to stop const...
# 23  Graham, Ian, “Dissidents Behind Failed Mortar ...
# 24  Leon Fooksman and Peter Franceschina, "Abortio...
# 25  Dennis B. Roddy, "What force drove Baumhammers...
# 26  Dennis B. Roddy, "What force drove Baumhammers...
# 27  Dennis B. Roddy, "What force drove Baumhammers...
# 28  Dennis B. Roddy, "What force drove Baumhammers...
# 29  Dennis B. Roddy, "What force drove Baumhammers...
# 30  Dennis B. Roddy, "What force drove Baumhammers...
# 31  John Mullin, “Paramilitary Cold War Hots Up," ...
# 32  Paul Shukovsky, "Animal-rights activist arrest...
# 33  Daniel McGrory, "Police thwart firebomb attack...
# 34  "N.H. Clinic Reopens After Suspicious Weekend ...
# 35  "Grand jury indicts two anarchists on arson ch...
# 36                                                NaN
# 37                                                NaN
# 38  Allison Tallmadge, "Opening Arguments begin in...
# 39                                                NaN
# 40  Maggie O'Kane and Nicholas Watt, "Belfast blas...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45  Monika Unsworth, "Arson attack on Ballymena sc...
# 46  "Animal-rights group suspected in fire at chic...
# 47  Jamie Macaskill, "Streets of Fear as Ulster Fa...
# 48  Shawn Pogatchnik, “Car bomb blasts police stat...
# 49  “CAR BOMB INJURES MAN IN NORTHERN IRELAND,” Ha...
# 50  Monika Unsworth, "Arson attack on Ballymena sc...
#
#                                                scite3  \
# 0   Justice Department Documents and Publications,...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Deric Henderson, “UK: LVF Blamed After Rival L...
# 6   Debra J. Saunders, "Save the Chickens," San Fr...
# 7                                                 NaN
# 8   Pamela J. Podger, "Animal-Rights Cell Says It ...
# 9   Ian Graham, “Ulster Peace in Crisis After Hote...
# 10  “Ulster: Device Explodes At Army Barracks; No ...
# 11                                                NaN
# 12  Christopher Hewitt, "Political Violence and Te...
# 13  Todd Spangler, "Western PA man charged with ha...
# 14  Todd Spangler, "Western PA man charged with ha...
# 15  Todd Spangler, "Western PA man charged with ha...
# 16  Todd Spangler, "Western PA man charged with ha...
# 17                                                NaN
# 18  “Mysterious Powder Found in IRS Return,” The A...
# 19                                                NaN
# 20                                                NaN
# 21  Cowan, Rosie,“Bomb Brings Warning of Dissident...
# 22  "List of Fires in Federal Indictment," Associa...
# 23                                                NaN
# 24  Clinic Security Department, "2000 Chronicle of...
# 25  Dennis B. Roddy, "Interviews show troubled min...
# 26  Dennis B. Roddy, "Interviews show troubled min...
# 27  Dennis B. Roddy, "Interviews show troubled min...
# 28  Dennis B. Roddy, "Interviews show troubled min...
# 29  Dennis B. Roddy, "Interviews show troubled min...
# 30  Dennis B. Roddy, "Interviews show troubled min...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  "Chronological History of Arsons and Bombings ...
# 35  Allison Tallmadge, "Activist found guilty of A...
# 36                                                NaN
# 37                                                NaN
# 38  "Two suspects plead not guilty to arson, bomb ...
# 39                                                NaN
# 40  "Explosive device found near British minister'...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45  "Anti-Catholic protests rekindled in Ballymena...
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  “Car-bomb blast injures Catholic man near Belf...
# 50  "Anti-Catholic protests rekindled in Ballymena...
#
#                       dbsource  INT_LOG  INT_IDEO INT_MISC  INT_ANY  \
# 0             Eco Project 2010        0         1        0        1
# 1                        CETIS        0         1        0        1
# 2   Anti-Abortion Project 2010       -9        -9        0       -9
# 3   Anti-Abortion Project 2010       -9        -9        0       -9
# 4                        CETIS       -9        -9        1        1
# 5                        CETIS        0         0        1        1
# 6             Eco Project 2010        0         1        0        1
# 7                        CETIS        0         1        0        1
# 8             Eco Project 2010        0         1        0        1
# 9                        CETIS        0         0        1        1
# 10                       CETIS        0         0        1        1
# 11                       CETIS       -9        -9        1        1
# 12            Eco Project 2010        0         1        0        1
# 13           UMD Miscellaneous       -9        -9        0       -9
# 14           UMD Miscellaneous       -9        -9        0       -9
# 15           UMD Miscellaneous       -9        -9        0       -9
# 16           UMD Miscellaneous       -9        -9        0       -9
# 17                       CETIS        0         1        0        1
# 18                       CETIS       -9        -9        0       -9
# 19            Eco Project 2010       -9        -9        0       -9
# 20                       CETIS       -9        -9        0       -9
# 21                       CETIS        0         0        1        1
# 22            Eco Project 2010        0         0        0        0
# 23                       CETIS        0         0        1        1
# 24  Anti-Abortion Project 2010       -9        -9        0       -9
# 25           UMD Miscellaneous       -9        -9        0       -9
# 26           UMD Miscellaneous       -9        -9        0       -9
# 27           UMD Miscellaneous       -9        -9        0       -9
# 28           UMD Miscellaneous       -9        -9        0       -9
# 29           UMD Miscellaneous       -9        -9        0       -9
# 30           UMD Miscellaneous       -9        -9        0       -9
# 31                       CETIS        0         0        1        1
# 32                       CETIS        0         1        0        1
# 33                       CETIS        0         1        1        1
# 34  Anti-Abortion Project 2010       -9        -9        0       -9
# 35            Eco Project 2010       -9        -9        0       -9
# 36                       CETIS       -9        -9        1        1
# 37                       CETIS       -9        -9        1        1
# 38            Eco Project 2010       -9        -9        0       -9
# 39                       CETIS       -9        -9        1        1
# 40             UMD Schmid 2012        0         1        1        1
# 41                       CETIS        0         0        1        1
# 42                       CETIS       -9        -9        1        1
# 43                       CETIS        0         0        1        1
# 44                       CETIS       -9        -9        1        1
# 45             UMD Schmid 2012       -9        -9        1        1
# 46            Eco Project 2010        0         1        0        1
# 47                       CETIS       -9        -9        1        1
# 48                       CETIS        0         0        1        1
# 49                       CETIS       -9        -9        1        1
# 50             UMD Schmid 2012       -9        -9        1        1
#
#                                               related
# 0                                                 NaN
# 1                                                 NaN
# 2                          200001030008, 200001030009
# 3                          200001030008, 200001030009
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  200003010004, 200003010005, 200003010006, 2000...
# 14  200003010004, 200003010005, 200003010006, 2000...
# 15  200003010004, 200003010005, 200003010006, 2000...
# 16  200003010004, 200003010005, 200003010006, 2000...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  200004280003, 200004280004, 200004280005, 2000...
# 26  200004280003, 200004280004, 200004280005, 2000...
# 27  200004280003, 200004280004, 200004280005, 2000...
# 28  200004280003, 200004280004, 200004280005, 2000...
# 29  200004280003, 200004280004, 200004280005, 2000...
# 30  200004280003, 200004280004, 200004280005, 2000...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45           200007000001, 200007170005, 200007190006
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50           200007000001, 200007170005, 200007190006
#
# [51 rows x 94 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# Given that this is an academic dataset maintained by a research university with documented criteria for how incidents are included, the data appears consistent and there are no concerns at this time for inconsistencies.
# </div>

# %% [markdown]
# ### Finalizing Dataset(s)

# %%
# Converting to .csv for continued use:

df_gtd.to_csv("gtd_uk_usa_v2.csv", index=False)

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
#
# <div class="alert alert-block alert-info">
# I did not necessarily find all four types of "dirty" data within the dataset. Much of the cleaning conducted during Checkpoint 3 related to removing superfluous or unnecessary data as it pertains to the analysis I intend to conduct. Null values were not inherently missing data but more often fields not applicable to an incident. Further, outliers are not inherently problematic when understanding this type of data as the outliers in and of themselves are important to note, recognize, and even research more; this is to say, outliers in this dataset are not problematic entries to be removed but interesting data points.
# </div>
#
# 2. Did the process of cleaning your data give you new insights into your dataset?
#
# <div class="alert alert-block alert-info">
# This process assisted in further reducing the size of my dataset and removing unneccessary fields. It also led me to reference the codebook for the dataset once more and better look at the numerical variables, such that I have additional ideas of relationships to explore and visualize.
# </div>
#
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
#
# <div class="alert alert-block alert-info">
# It may be interesting to identify the more impactful and "known" terrorism incidents and demarcate them on my visualizations. This could also add further context to spikes in activity and/or those killed/injured.
# </div>
